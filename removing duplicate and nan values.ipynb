# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         936 non-null    object
#  1   Gender             858 non-null    object
#  2   Start Date         1003 non-null   object
#  3   Last Login Time    1003 non-null   object
#  4   Salary             1003 non-null   int64
#  5   Bonus %            1003 non-null   float64
#  6   Senior Management  936 non-null    object
#  7   Team               960 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.8+ KB

# %%
len(df)
# Out:
# 1003

# %%
nan_rows = df[df.isnull().T.any().T]
nan_rows
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 20        Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ..         ...     ...         ...             ...     ...      ...
# 961    Antonio     NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor     NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen     NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# 10               True              NaN
# 20               True            Legal
# 22               True  Client Services
# ..                ...              ...
# 961             False            Legal
# 972              True            Sales
# 985             False            Legal
# 989             False            Legal
# 995             False     Distribution
#
# [236 rows x 8 columns]

# %%
nan_specific_rows = df[df['Team'].isnull()]
nan_specific_rows
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 10        Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 23           NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 32           NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 91         James     NaN   1/26/2005        11:00 PM  128771    8.309
# 109  Christopher    Male   4/22/2000        10:15 AM   37919   11.449
# 139          NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 199     Jonathan    Male   7/17/2009         8:15 AM  130581   16.736
# 258      Michael    Male   1/24/2002         3:04 AM   43586   12.659
# 290       Jeremy    Male   6/14/1988         6:20 PM  129460   13.657
# 314        Bobby    Male   3/31/1996         5:40 PM  112117    6.338
# 367       Edward    Male    8/4/1989         6:06 AM   66067   10.957
# 382          NaN  Female   4/18/1996         3:57 PM  107024   12.182
# 434        Joyce  Female    2/7/1995         7:38 AM   50701   14.227
# 438        Jason    Male  11/20/1998         2:54 PM   69244    6.220
# 445        Chris    Male  12/12/2006         1:57 AM   71642    1.496
# 479      Richard    Male    7/4/1997        11:47 AM   47647   18.787
# 512        Wanda  Female    4/6/1993         3:11 AM   78883   19.695
# 513        Jimmy    Male  11/19/2013         7:29 PM   63549   19.624
# 520        Peter    Male   2/22/2003         9:09 AM   56580    8.411
# 567          NaN  Female    4/1/1980         8:04 PM   48141   12.605
# 573     Kimberly  Female  12/30/1981         4:51 AM   81800    5.435
# 580        Harry    Male   1/27/1985         8:18 PM   65482   18.089
# 626          NaN  Female   4/13/1997         8:03 AM  131755    2.930
# 634         Carl    Male   3/30/1987         5:59 PM   75598   19.289
# 635        Randy    Male   9/27/2000         3:04 AM   89831   13.047
# 647       Donald    Male    4/6/1988        10:00 AM  122920    5.320
# 669       Joseph     NaN   3/28/1982         1:05 PM   86564   11.879
# 684        Alice  Female   1/21/2016         5:07 PM  117787   10.485
# 706         Todd    Male    7/4/1993         6:53 PM  128175   18.473
# 726       Daniel    Male   2/29/2016         4:04 AM   77287   13.000
# 753      Antonio    Male    6/6/1999        10:54 PM   41928    5.478
# 774          NaN  Female   6/18/2000         7:36 AM  106428   10.867
# 781     Lawrence    Male    7/3/1995        10:55 PM   46378    9.127
# 794       Nicole  Female    3/1/2004         5:17 PM   44021   10.286
# 826          NaN     NaN    8/1/1988         1:35 AM   87103    5.665
# 850      Charles    Male    9/3/1997        10:04 AM  148291    6.002
# 851        Bobby    Male   8/19/1996         1:16 AM  147842   16.158
# 853      Mildred  Female    4/6/2007        10:06 PM  139284   11.390
# 855      Phillip     NaN  10/20/2003        11:09 AM   89700    2.277
# 864         Ryan    Male  11/16/2012         1:47 PM   57292    6.010
# 912          Joe    Male   12/8/1998        10:28 AM  126120    1.020
# 951          NaN  Female   9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23                NaN  NaN
# 32                NaN  NaN
# 91              False  NaN
# 109             False  NaN
# 139               NaN  NaN
# 199              True  NaN
# 258             False  NaN
# 290              True  NaN
# 314             False  NaN
# 367              True  NaN
# 382               NaN  NaN
# 434              True  NaN
# 438              True  NaN
# 445             False  NaN
# 479              True  NaN
# 512             False  NaN
# 513             False  NaN
# 520              True  NaN
# 567               NaN  NaN
# 573              True  NaN
# 580             False  NaN
# 626               NaN  NaN
# 634             False  NaN
# 635              True  NaN
# 647             False  NaN
# 669              True  NaN
# 684             False  NaN
# 706              True  NaN
# 726              True  NaN
# 753              True  NaN
# 774               NaN  NaN
# 781             False  NaN
# 794             False  NaN
# 826               NaN  NaN
# 850             False  NaN
# 851              True  NaN
# 853              True  NaN
# 855              True  NaN
# 864             False  NaN
# 912             False  NaN
# 951               NaN  NaN

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#      First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 1000     Albert   Male  5/15/2012         6:24 PM  129949   10.169
# 1001     Albert   Male  5/15/2012         6:24 PM  129949   10.169
# 1002     George   Male  6/21/2013         5:47 PM   98874    4.479
#
#      Senior Management       Team
# 1000              True      Sales
# 1001              True      Sales
# 1002              True  Marketing

# %%
df = df.dropna(subset=['Team', 'Salary'])

# %%
df
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ...         ...     ...        ...             ...     ...      ...
# 998       Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1000     Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1001     Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1002     George    Male  6/21/2013         5:47 PM   98874    4.479
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ...                ...                   ...
# 998              False  Business Development
# 999               True                 Sales
# 1000              True                 Sales
# 1001              True                 Sales
# 1002              True             Marketing
#
# [960 rows x 8 columns]

# %%
df = df.dropna(how='any', axis=0)

# %%
df
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ...         ...     ...        ...             ...     ...      ...
# 998       Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1000     Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1001     Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1002     George    Male  6/21/2013         5:47 PM   98874    4.479
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ...                ...                   ...
# 998              False  Business Development
# 999               True                 Sales
# 1000              True                 Sales
# 1001              True                 Sales
# 1002              True             Marketing
#
# [767 rows x 8 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop_duplicates(keep=False, inplace=True)
# Out:
# /home/soumik/anaconda3/envs/kaggle/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 992              True               Finance
# 993              True           Engineering
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
#
# [762 rows x 8 columns]

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
len(duplicate_rows)
# Out:
# 0
